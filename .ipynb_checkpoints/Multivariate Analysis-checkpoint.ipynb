# %% [markdown]
# # Multivariate analysis: Modeling

# %% [markdown]
# ![](https://docs.microsoft.com/en-us/azure/machine-learning/team-data-science-process/media/overview/tdsp-lifecycle2.png "Data Science Lifecycle")

# %% [markdown]
# Interesting sources:
# - https://learn.datacamp.com/courses/machine-learning-with-tree-based-models-in-python
# - https://www.datacamp.com/community/tutorials/decision-tree-classification-python

# %% [markdown]
# We have seen that we can uncover correlations by using bivariate analyis. This also raises the question: If we extract information from multiple columns (Multivariate analysis), could we use these correlations to calculate/predict the value of a column for rows that do not yet have a value?
#
# For example:
# - Can we calculate if a customer will churn (= We lose the customer)?
# - Can we calculate if a customer would use a certain product? (Product recommendation)
# - Can we calculate if a mail is spam or not?
# - Can we calculate if a financial transaction is fraudulent or not?
# - Can we calculate if a customer will be able to pay back their loan or not?
# - Can we calculate the price people are willing to pay for a house?
# - Can we calculate the salary a student will earn in the future?
# - ...
#
# Just as we used math/statistics to support to explore the data one column at a time (Univariate) and per combination of two columns (Bivariate analysis), we will use machine learning algorithms to extract information across multiple columns (Multivariate analysis) and to build data products.
#
# Machine learning is:
# - Machine learning is a method of data analysis that automates analytical model building. It is a branch of artificial intelligence based on the idea that systems can learn from data, identify patterns and make decisions with minimal human intervention. (https://www.sas.com/en_us/insights/analytics/machine-learning.html#:~:text=Machine%20learning%20is%20a%20method,decisions%20with%20minimal%20human%20intervention.)
# - Machine learning (ML) is the study of computer algorithms that improve automatically through experience.[1] It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2] Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks. (https://en.wikipedia.org/wiki/Machine_learning)
#
# Examples of data products could include:
# - A product recommender
# - A customer churn predictor
# - A mail labeler (Primary, promotion, social, spam, etc.)
# - Sentiment analyser for social media messages
# - ...

# %% [markdown]
# ![](https://miro.medium.com/max/1204/1*qYoU2VTBsORAfhkfiluURQ.png)

# %% [markdown]
# We will refer to the column that we are trying to calculate as the <b>target variable</b>. The columns used for this calculation will be refered to as the <b>feature variables</b>.
#
# For example, if we want to predict a person's shoe size based on their body length:
# - The shoe size is the target variable
# - The body length is the feature variable
#
# Extra info: The terms 'target' and 'feature' are borrowed from the field of Machine Learning. In the field of statistics, we refer to the target variable as the dependent variable and we refer to the feature variables as the independent variables.

# %% [markdown]
# # Classification

# %% [markdown]
# When the target variable is a categorical variable then we refer to this task as a classification task.
#
# Examples of classification tasks:
# - Predict if a customer will churn.
# - Predict if a customer will use a specific product.
# - Label mails as spam.
# - Label financial transactions as fraudulent.
# - Label a social media message as positive, neutral or negative.
# - Predict if a customer of the bank will be able to pay back the loan.
#
# Examples of machine learning algorithms that we could use for classification:
# - Decision trees
# - Random forests
# - Logistic regression
# - Neural networks
# - Naive bayes

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ![](https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png "Iris dataset")

# %% [markdown]
# ## Training the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features= ['sepal_length']
dt = DecisionTreeClassifier(max_depth = 1) # Increase max_depth to see effect in the plot
dt.fit(iris[features], iris['species'])
# Out:
# DecisionTreeClassifier(max_depth=1)

# %% [markdown]
# `conda install -c anaconda graphviz`
# `conda install -c anaconda python-graphviz`
# `conda install -c anaconda pydot`
# If the code below still does not work, install from here: (https://graphviz.org/download/)

# %%
from sklearn import tree
import graphviz

def plot_tree_classification(model, features, class_names):
    # Generate plot data
    dot_data = tree.export_graphviz(model, out_file=None, 
                          feature_names=features,  
                          class_names=class_names,  
                          filled=True, rounded=True,  
                          special_characters=True)  

    # Turn into graph using graphviz
    graph = graphviz.Source(dot_data)  

    # Write out a pdf
    graph.render("decision_tree")

    # Display in the notebook
    return graph

# %%
plot_tree_classification(dt, features, np.sort(iris.species.unique()))

# %% [markdown]
# ## Evaluating the model

# %%
predictions = dt.predict(iris[features])

# %%
predictions
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'virginica', 'virginica', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'virginica', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'setosa',
#        'virginica', 'setosa', 'setosa', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
# ...

# %%
def calculate_accuracy(predictions, actuals):
    if(len(predictions) != len(actuals)):
        raise Exception("The amount of predictions did not equal the amount of actuals")
    
    return (predictions == actuals).sum() / len(actuals)

# %%
calculate_accuracy(predictions, iris.species)
# Out:
# 0.6266666666666667

# %% [markdown]
# ### Test/train split

# %%
from sklearn.model_selection import train_test_split

# %%
iris_train, iris_test = train_test_split(iris, test_size=0.3, random_state=42, stratify=iris['species'])
print(iris_train.shape, iris_test.shape)
# Out:
# (105, 5) (45, 5)

# %%
features= ['sepal_length', 'sepal_width']
dt_classification = DecisionTreeClassifier(max_depth = 10) # Increase max_depth to see effect in the plot
dt_classification.fit(iris_train[features], iris_train['species'])
# Out:
# DecisionTreeClassifier(max_depth=10)

# %% [markdown]
# ### Overfitting

# %%
predictionsOnTrainset = dt_classification.predict(iris_train[features])
predictionsOnTestset = dt_classification.predict(iris_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, iris_train.species)
accuracyTest = calculate_accuracy(predictionsOnTestset, iris_test.species)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.9333333333333333
# Accuracy on test set 0.6444444444444445

# %% [markdown]
# ## Portfolio assignment 15
# 30 min: Train a decision tree to predict the species of a penguin based on their characteristics.
# - Split the penguin dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeClassifier. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# <b>Note</b>: Some machine learning algorithms can not handle missing values. You will either need to
#  - replace missing values (with the mean or most popular value). For replacing missing values you can use .fillna(\<value\>) https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html
#  - remove rows with missing data.  You can remove rows with missing data with .dropna() https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# - Use your decision tree model to make predictions for both the train and test set.
# - Calculate the accuracy for both the train set predictions and test set predictions.
# - Is the accurracy different? Did you expect this difference?
# - Use the plot_tree_classification function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?
#
# Optional: Perform the same tasks but try to predict the sex of the pinguin based on the other columns

# %%
penguins = sns.load_dataset("penguins")
penguins = penguins.dropna()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
penguins_train, penguins_test = train_test_split(penguins,test_size=0.3, random_state=42, stratify=penguins['species'])
print(penguins_train.shape, penguins_test.shape)
# Out:
# (233, 7) (100, 7)

# %%
features = ['bill_length_mm', 'bill_depth_mm']
penguins_dt = DecisionTreeClassifier(max_depth = 3) # Increase max_depth to see effect in the plot
penguins_dt.fit(penguins_train[features], penguins_train['species'])
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
predictionsOnTrainset = penguins_dt.predict(penguins_train[features])
predictionsOnTestset = penguins_dt.predict(penguins_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, penguins_train.species)
accuracyTest = calculate_accuracy(predictionsOnTestset, penguins_test.species)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.944206008583691
# Accuracy on test set 0.92

# %% [markdown]
# De accuracy op beide sets is zeer goed, maar de accuracy op de training set is beter, omdat deze splitst op de exacte waarden waar alle rassen zo goed mogelijk verdeeld zijn. De waarde waar een splitsing van de rassen plaatsvindt is waarschijnlijk net anders op de test set en daardoor is de accuracy iets minder goed.

# %%
plot_tree_classification(penguins_dt, features, np.sort(penguins.species.unique()))

# %% [markdown]
# De boom probeert bij de eerste splitsing een zo puur mogelijke bucket te maken en dat licht blijkbaar bij een bill length van minder dan of gelijk aan 42.35. Hierdoor krijg je namelijk een bucket waar 95 penguins van het ras Adelie in zitten en meer 1 penguin van ieder ander ras. Vervolgens worden er twee splitsingen gedaan om de twee penguins van een ander ras uit de pure bucket te halen. De bucket met snavellengtes langer dan de splitswaarde is minder puur. Op deze bucket wordt vervolgens een splitsing gedaan om een zo puur mogelijke bucket met Gentoo penguins te maken. In de laatste splitsing wordt de bucket met de overgebleven Chinstrap penguins zo puur mogelijk gemaakt.

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)

# %% [markdown]
# ## Portfolio assignment 16
# 30 min: Train a decision tree to predict one of the categorical columns of your own dataset.
# - Split your dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeClassifier. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# - Use your decision tree model to make predictions for both the train and test set.
# - Calculate the accuracy for both the train set predictions and test set predictions.
# - Is the accurracy different? Did you expect this difference?
# - Use the plot_tree function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?
#
# ![](https://i.imgur.com/0v1CGNV.png)

# %%
movies = pd.read_csv('./imdb_top_1000.csv', thousands=',')
movies['Runtime'] = [i.split()[0] for i in movies['Runtime']]
movies['Runtime'] = movies['Runtime'].astype(int)
movies = movies[movies.Released_Year.str.isnumeric()]
movies['Released_Year'] = movies['Released_Year'].astype(int)
# Splitst de genre's op in nieuwe rijen
# Gebruik enkel voor tellen van genre's
moviesExplodeGenre = movies.assign(Genre = movies.Genre.str.split(", ")).explode('Genre')
# Splitst de genre's op in nieuwe kolommen
# Gebruik wanneer exploden rommelt met gegevens
movies[['Genre1', 'Genre2', 'Genre3']] = movies['Genre'].str.split(', ', 2, expand=True)
movies = movies.dropna()
movies.head()
# Out:
#                                           Poster_Link  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
#
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 7                                    Schindler's List           1993
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
#
#    Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           UA      152       Action, Crime, Drama          9.0
# 5            U      201   Action, Adventure, Drama          8.9
# ...

# %%
movies_train, movies_test = train_test_split(movies ,test_size=0.3, random_state=42)
print(movies_train.shape, movies_test.shape)
# Out:
# (333, 19) (144, 19)

# %%
features = ['Runtime', 'Released_Year', 'Gross']
movies_dt = DecisionTreeClassifier(max_depth = 5) # Increase max_depth to see effect in the plot
movies_dt.fit(movies_train[features], movies_train['Genre1'])
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
predictionsOnTrainset = movies_dt.predict(movies_train[features])
predictionsOnTestset = movies_dt.predict(movies_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, movies_train.Genre1)
accuracyTest = calculate_accuracy(predictionsOnTestset, movies_test.Genre1)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.46546546546546547
# Accuracy on test set 0.3125

# %% [markdown]
# Er is een groot verschil tussen de accuracy van de training set en de test set. Dit is waarschijnlijk omdat geen van de numerieke kolommen in deze dataset een sterke correlatie heeft met de categorische waarden in de dataset. Een accuracy op de test set van 31-33% klinkt in eerste instantie ook niet heel goed, maar aangezien dit is gedaan gebaseerd op vermoedelijk ongerelateerde waarden en er veel verschillende genres in deze dataset zitten ben ik verbaasd dat het zo goed is. Er zijn 11 genres in deze dataset, dus deze accuracy is ruim drie keer beter dan willekeurig gokken.

# %%
plot_tree_classification(movies_dt, features, np.sort(movies.Genre1.unique()))

# %% [markdown]
# Omdat de genres in deze dataset niet gelijk zijn verdeeld komt er in de decision tree prioriteit om pure buckets te maken van de meest populaire genres. Dit is te zien aan de values van de bovenste node en het feit dat bijna alle buckets de populaire genres als class hebben.

# %% [markdown]
# # Regression

# %% [markdown]
# When the target variable is a numerical variable then we refer to this task as a regression task.
#
# Examples of regression tasks:
# - Predict the price people are willing to pay for a house.
# - Predict the salary a student will earn in the future.
#
# Examples of machine learning algorithms that we could use for regression:
# - Decision trees
# - Random forests
# - Linear regression
# - Neural networks

# %%
iris.corr() # to find out which features correlate with sepal_length
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
features= ['petal_length'] # add 'petal_width' ('species' does not work; categorical is not implemented in DT of sciki learn)
dt_regression = DecisionTreeRegressor(max_depth = 1) # Increase max_depth to see effect in the plot
dt_regression.fit(iris_train[features], iris_train['sepal_length'])
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
from sklearn import tree
import graphviz

def plot_tree_regression(model, features):
    # Generate plot data
    dot_data = tree.export_graphviz(model, out_file=None, 
                          feature_names=features,  
                          filled=True, rounded=True,  
                          special_characters=True)  

    # Turn into graph using graphviz
    graph = graphviz.Source(dot_data)  

    # Write out a pdf
    graph.render("decision_tree")

    # Display in the notebook
    return graph

# %%
plot_tree_regression(dt_regression, features)

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ![](http://www.aimlfront.com/images/rmse1.png "RMSE")

# %%
def calculate_rmse(predictions, actuals):
    if(len(predictions) != len(actuals)):
        raise Exception("The amount of predictions did not equal the amount of actuals")
    
    return (((predictions - actuals) ** 2).sum() / len(actuals)) ** (1/2)

# %%
predictionsOnTrainset = dt_regression.predict(iris_train[features])
predictionsOnTestset = dt_regression.predict(iris_test[features])

rmseTrain = calculate_rmse(predictionsOnTrainset, iris_train.sepal_length)
rmseTest = calculate_rmse(predictionsOnTestset, iris_test.sepal_length)

print("RMSE on training set " + str(rmseTrain))
print("RMSE on test set " + str(rmseTest))
# Out:
# RMSE on training set 0.5227236006263037
# RMSE on test set 0.5093039370846077

# %% [markdown]
# ## Portfolio assignment 17
# 30 min: Train a decision tree to predict the body_mass_g of a penguin based on their characteristics.
# - Split the penguin dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeRegressor. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# <b>Note</b>: Some machine learning algorithms can not handle missing values. You will either need to
#  - replace missing values (with the mean or most popular value). For replacing missing values you can use .fillna(\<value\>) https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html
#  - remove rows with missing data.  You can remove rows with missing data with .dropna() https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# - Use your decision tree model to make predictions for both the train and test set.
# - Calculate the RMSE for both the train set predictions and test set predictions.
# - Is the RMSE different? Did you expect this difference?
# - Use the plot_tree_regression function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?

# %%
penguins = sns.load_dataset("penguins")
penguins = penguins.dropna()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
penguins.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
penguins_train, penguins_test = train_test_split(penguins,test_size=0.3, random_state=42, stratify=penguins['species'])
print(penguins_train.shape, penguins_test.shape)
# Out:
# (233, 7) (100, 7)

# %%
features = ['flipper_length_mm', 'bill_length_mm']
penguins_regression = DecisionTreeRegressor(max_depth=3)
penguins_regression.fit(penguins_train[features], penguins_train['body_mass_g'])
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
predictionsOnTrainset = penguins_regression.predict(penguins_train[features])
predictionsOnTestset = penguins_regression.predict(penguins_test[features])

rmseTrain = calculate_rmse(predictionsOnTrainset, penguins_train.body_mass_g)
rmseTest = calculate_rmse(predictionsOnTestset, penguins_test.body_mass_g)

print("RMSE on training set " + str(rmseTrain))
print("RMSE on test set " + str(rmseTest))
# Out:
# RMSE on training set 348.37874508841065
# RMSE on test set 403.8548465547442

# %%
print("RMSE als percentage afwijking van gemiddeld gewicht is %" + str(rmseTest/penguins['body_mass_g'].mean()*100))
# Out:
# RMSE als percentage afwijking van gemiddeld gewicht is %9.59946207236017

# %% [markdown]
# Ik dacht toen ik de RMSE waardes zag dat ik iets heel erg mis had gedaan, maar toen herinnerde ik me dat body_mass_g hoge waardes heeft. Ik heb dus de RMSE als percentage in plaats van getal uitgewerkt en dat ziet er een stuk beter uit. Een gemiddelde afwijking van ongeveer 10% is niet slecht.

# %%
plot_tree_regression(penguins_regression, features)

# %% [markdown]
# De tree probeert bij iedere stap een bucket op te splitsen in twee buckets die een zo laag mogelijke MSE(Mean Square Error) hebben. Dit betekent dat de gemiddelde waarde van alle waardes in de bucket zo weinig mogelijk moet afwijken van de waardes in de bucket. Stel je hebt een bucket met waarden 100 en 500. De gemiddelde waarde is dan 300 met een gemiddelde afwijking van 200. Door bij iedere stap deze gemiddelde afwijking zo laag mogelijk te krijgen, wordt er voor gezorgd dat waarden die bij elkaar in de buurt zitten gegroepeerd worden. Hierdoor kan met minder afwijking voorspeld worden wat de body mass zal zijn.

# %% [markdown]
# ## Portfolio assignment 18
# 30 min: Train a decision tree to predict one of the numerical columns of your own dataset.
# - Split your dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeRegressor. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# - Use your decision tree model to make predictions for both the train and test set.
# - Calculate the RMSE for both the train set predictions and test set predictions.
# - Is the accurracy different? Did you expect this difference?
# - Use the plot_tree function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?
#
# ![](https://i.imgur.com/0v1CGNV.png)

# %%
movies = pd.read_csv('./imdb_top_1000.csv', thousands=',')
movies['Runtime'] = [i.split()[0] for i in movies['Runtime']]
movies['Runtime'] = movies['Runtime'].astype(int)
movies = movies[movies.Released_Year.str.isnumeric()]
movies['Released_Year'] = movies['Released_Year'].astype(int)
# Splitst de genre's op in nieuwe rijen
# Gebruik enkel voor tellen van genre's
moviesExplodeGenre = movies.assign(Genre = movies.Genre.str.split(", ")).explode('Genre')
# Splitst de genre's op in nieuwe kolommen
# Gebruik wanneer exploden rommelt met gegevens
movies[['Genre1', 'Genre2', 'Genre3']] = movies['Genre'].str.split(', ', 2, expand=True)
movies = movies.dropna()
movies.head()
# Out:
#                                           Poster_Link  \
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
#
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 7                                    Schindler's List           1993
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
#
#    Certificate  Runtime                      Genre  IMDB_Rating  \
# 2           UA      152       Action, Crime, Drama          9.0
# 5            U      201   Action, Adventure, Drama          8.9
# ...

# %%
movies_train, movies_test = train_test_split(movies ,test_size=0.3, random_state=42)
print(movies_train.shape, movies_test.shape)
movies.corr()
# Out:
# (333, 19) (144, 19)
#                Released_Year   Runtime  IMDB_Rating  Meta_score  No_of_Votes  \
# Released_Year       1.000000 -0.031175    -0.132215   -0.279107     0.267523
# Runtime            -0.031175  1.000000     0.247998   -0.005387     0.193951
# IMDB_Rating        -0.132215  0.247998     1.000000    0.302056     0.588152
# Meta_score         -0.279107 -0.005387     0.302056    1.000000     0.061881
# No_of_Votes         0.267523  0.193951     0.588152    0.061881     1.000000
# Gross               0.282779  0.154058     0.167099    0.030354     0.586976
#
#                   Gross
# Released_Year  0.282779
# Runtime        0.154058
# IMDB_Rating    0.167099
# Meta_score     0.030354
# No_of_Votes    0.586976
# Gross          1.000000

# %%
features = ['Gross', 'No_of_Votes']
movies_regressor = DecisionTreeRegressor(max_depth = 2) # Increase max_depth to see effect in the plot
movies_regressor.fit(movies_train[features], movies_train['Meta_score'])
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
predictionsOnTrainset = movies_regressor.predict(movies_train[features])
predictionsOnTestset = movies_regressor.predict(movies_test[features])

rmseTrain = calculate_rmse(predictionsOnTrainset, movies_train.Meta_score)
rmseTest = calculate_rmse(predictionsOnTestset, movies_test.Meta_score)

print("RMSE on training set " + str(rmseTrain))
print("RMSE on test set " + str(rmseTest))
# Out:
# RMSE on training set 12.190309505594545
# RMSE on test set 12.269103668838516

# %% [markdown]
# Er is bijna geen verschil tussen de training set en de test set. Dit had ik verwacht aangezien de features sterke correlatie hebben met de voorspelde waarde en omdat de tree niet heel diep gaat. Hierdoor wordt voorkomen dat de tree hele specifieke splitsingen gaat maken die op de test set niet zouden werken.

# %%
print("RMSE als percentage afwijking van gemiddelde Meta score is %" + str(rmseTest/movies['Meta_score'].mean()*100))
# Out:
# RMSE als percentage afwijking van gemiddelde Meta score is %16.001865994137678

# %%
plot_tree_regression(movies_regressor, features)

# %% [markdown]
# Omdat de correlatie tussen de features en de voorspelde waarde zo sterk is is het heel goed te begrijpen wat de tree aan het doen is. Eerst wordt gesplitst op de omzet, omdat een film met hoge omzet vaak en hoge omzet heeft een vice versa. In de volgende stap wordt er gesplitst op het aantal stemmen, omdat een film met weinig stemmen waarschijnlijk niet veel gekeken is. Dit is dan waarschijnlijk omdat de film niet zo goed is.
